# %% [markdown]
# <a href="https://colab.research.google.com/github/Kashaf-Abdullah/20sw027_DSA_LAB/blob/main/LAB7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#store data
import numpy as np
import pandas as pd
#visualize
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline


diam=pd.read_csv('/content/Diamonds Prices2022.csv')

print(diam.shape)
diam.head()
# Out:
# (53943, 11)
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
diam.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
diam.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
diam.isnull().count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9299d6766bd1> in <cell line: 1>()
# ----> 1 diam.isnull().count()
#
# NameError: name 'diam' is not defined

# %%
diam['color'].value_counts()

# %%
#Barchart
sb.countplot(data=df,x='color')

# %%
order=diam['color'].value_counts().index
order

# %%
sb.countplot(data=df,x='color',color=base_colour,order=order)

# %%
#piechart
sorted_counts = diam['color'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,
        counterclock = False);
plt.axis('square');

# %%
bins=np.arange(0, diam['price'].max()+5, 5) # start, end, and step size
plt.hist(data=df, x='price', bins=bins);

# %%
bins=np.arange(0, diam['depth'].max()+5, 5) # start, end, and step size
plt.hist(data=df, x='depth', bins=bins);

# %%
bins=np.arange(0, diam['depth'].max()+5, 5) # start, end, and step size
plt.hist(data=df, x='depth', bins=bins);
plt.xscale('log');

# %%
bins = 10 ** np.arange(1.6, 2+0.2, 0.2) # start, end, and step size
plt.hist(data=diam, x='depth', bins=bins);
plt.xscale('log');

# %%
#Scatterplot
plt.scatter(data=diam, x='x',y='y')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

# %%
sb.regplot(data=diam, x='x',y='y')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

# %%
#Add Transparency
sb.regplot(data=diam, x='x',y='y',x_jitter=0.3,scatter_kws={'alpha': 1/20});


#darker area shows the overlap of the data ; this is area Where the main bulk of the data lies.

# %%
#Heat maps
plt.hist2d(data=diam, x='x',y='y',cmin=0.5)
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')

# %%
#Heat maps
plt.hist2d(data=diam, x='x',y='y',cmin=0.5,cmap='viridis_r')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')

# %%
#boxplot
base_color = sb.color_palette()[0]
sb.boxplot(data=diam, x='cut', y='table',color=base_color)
plt.xticks(rotation=15)
